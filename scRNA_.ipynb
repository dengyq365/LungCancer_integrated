# %%
import scanpy as sc
import matplotlib as mpl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


plt.rcParams["pdf.fonttype"] = 42  # 42 represent TrueType 
plt.rcParams["ps.fonttype"] = 42
mpl.rcParams['text.color'] = "black"
mpl.rcParams['figure.facecolor'] = 'white'
mpl.rcParams['axes.facecolor'] = 'white'
mpl.rcParams["savefig.facecolor"] = 'white'
sc.set_figure_params(dpi_save=300)

# %%
adata = sc.read_h5ad("NSCLC_DataSet/NSCLC_ALL.h5ad")

# %%
sc.pl.umap(adata, color = "celltype_LV1", legend_loc = 'on data', frameon = False, legend_fontsize = 'x-small')

# %%
sc.pl.umap(adata, color = "source",frameon = False, legend_fontsize = 'x-small')

# %%
adata_T = sc.read_h5ad("NSCLC_DataSet/NSCLC_Lymphocytes.h5ad")

# %%
sc.pl.umap(adata_T, color = "celltype_LV2",frameon = False, legend_fontsize = 'x-small', legend_loc = 'on data')

# %%
adata_epi = sc.read_h5ad("NSCLC_DataSet/NSCLC_epithelial.h5ad")

# %%
sc.pl.umap(adata_epi, color = "celltype_LV2",frameon = False, legend_fontsize = 'x-small', legend_loc = 'on data')

# %%
adata_myeloid = sc.read_h5ad("NSCLC_DataSet/NSCLC_myeloid.h5ad")

# %%
sc.pl.umap(adata_myeloid, color = "celltype_LV2",frameon = False, legend_fontsize = 'x-small', legend_loc = 'on data')

# %%
adata_stromal = sc.read_h5ad("NSCLC_DataSet/NSCLC_stromal.h5ad")

# %%
sc.pl.umap(adata_stromal, color = "celltype_LV2",frameon = False, legend_fontsize = 'x-small', legend_loc = 'on data')
